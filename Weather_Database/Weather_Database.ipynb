# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import matplotlib.pyplot as plt
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Test to see if the above code successfully zipped the two lists. 

coordinates = list(lat_lngs)
print(coordinates[:3])
# Out:
# [(78.94050553310691, -146.69719509089992), (-6.553098147897558, -160.35407268134318), (-89.91186609879846, -135.86298528306483)]

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 784

# %%
# Base url for API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7ed6207ebdf7a3629fda9718ad01bfb3&q="

# %%
first_city = cities[0]
first_city
# Out:
# 'barrow'

# %%
query_url = url + first_city
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7ed6207ebdf7a3629fda9718ad01bfb3&q=barrow

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + cities[i]

# %%
cities
# Out:
# ['barrow',
#  'faanui',
#  'rikitea',
#  'carauari',
#  'sao joao da barra',
#  'saldanha',
#  'taganak',
#  'punta arenas',
#  'marshall',
#  'kaitangata',
#  'illoqqortoormiut',
#  'saint-philippe',
#  'norman wells',
#  'atar',
#  'kharan',
#  'tsihombe',
#  'tuktoyaktuk',
#  'manavalakurichi',
#  'hithadhoo',
#  'jalu',
#  'wulanhaote',
#  'haines junction',
#  'bethel',
#  'bluff',
#  'saint george',
#  'narsaq',
#  'saskylakh',
#  'nalut',
#  'nikolskoye',
#  'new norfolk',
#  'ribeira grande',
#  'kholtoson',
#  'palmer',
#  'taolanaro',
#  'saint-georges',
#  'rawson',
#  'ostrovnoy',
#  'jamestown',
#  'barentsburg',
#  'englehart',
#  'sao joao de pirabas',
#  'clyde river',
#  'kodiak',
#  'samusu',
#  'tasiilaq',
#  'la ronge',
#  'mataura',
#  'cape town',
#  'ucluelet',
#  'preeceville',
#  'nelson bay',
#  'belushya guba',
#  'evensk',
#  'pimentel',
#  'khonuu',
#  'pevek',
#  'apostolove',
#  'port elizabeth',
#  'ponta do sol',
#  'tiksi',
#  'albany',
#  'date',
#  'matveyevka',
#  'karasjok',
#  'provideniya',
#  'teeli',
#  'pontal do parana',
#  'zhangye',
#  'waingapu',
#  'cumaribo',
#  'pangnirtung',
#  'nhulunbuy',
#  'jonesboro',
#  'lavrentiya',
#  'chillan',
#  'aklavik',
#  'nishihara',
#  'nizhneyansk',
#  'bend',
#  'umm kaddadah',
#  'angra',
#  'comodoro rivadavia',
#  'hilo',
#  'koumac',
#  'tornio',
#  'atuona',
#  'tongliao',
#  'ushuaia',
#  'thompson',
#  'katha',
#  'bilibino',
#  'yerbogachen',
#  'utiroa',
#  'caravelas',
#  'busselton',
#  'sola',
#  'kanlagay',
#  'arantangi',
#  'saundatti yellamma',
#  'chuy',
#  'castro',
#  'calvia',
#  'pocone',
#  'lebu',
#  'attawapiskat',
#  'yulara',
#  'praia da vitoria',
#  'banda aceh',
#  'kenora',
#  'cherskiy',
#  'alofi',
#  'ust-kuyga',
#  'lalomanu',
#  'trelew',
#  'seymchan',
#  'brazzaville',
#  'aksarka',
#  'havre',
#  'harrisonville',
#  'kahului',
#  'vaini',
#  'konstantinovka',
#  'murgab',
#  'poso',
#  'bambous virieux',
#  'maraa',
#  'puerto escondido',
#  'marawi',
#  'muros',
#  'qaanaaq',
#  'anacortes',
#  'saint-louis',
#  'makarov',
#  'kapaa',
#  'tarakan',
#  'nauchnyy gorodok',
#  'neuquen',
#  'cururupu',
#  'kavaratti',
#  'khatanga',
#  'magistralnyy',
#  'mangan',
#  'zaporizhzhya',
#  'puerto ayora',
#  'airai',
#  'jiuquan',
#  'ngukurr',
#  'aykhal',
#  'coahuayana',
#  'alugan',
#  'port hedland',
#  'longyearbyen',
#  'himora',
#  'biloela',
#  'sur',
#  'costinesti',
#  'nador',
#  'turukhansk',
#  'flinders',
#  'hanzhong',
#  'hobart',
#  'sioux lookout',
#  'sisimiut',
#  'taltal',
#  'kindu',
#  'morlaix',
#  'north bend',
#  'velyka lepetykha',
#  'la orilla',
#  'cravo norte',
#  'pag',
#  'olinda',
#  'kostomuksha',
#  'ilebo',
#  'ilulissat',
#  'komsomolskiy',
#  'hambantota',
#  'sitka',
#  'sangar',
#  'carnarvon',
#  'rio tuba',
#  'luau',
#  'hasaki',
#  'berlevag',
#  'presidencia roque saenz pena',
#  'victor harbor',
#  'solovetskiy',
#  'port alfred',
#  'marzuq',
#  'lorengau',
#  'nome',
#  'hermanus',
#  'salalah',
#  'edd',
#  'pisco',
#  'teguise',
#  'bredasdorp',
#  'mackay',
#  'belaya gora',
#  'puerto el triunfo',
#  'upernavik',
#  'manokwari',
#  'dikson',
#  'geraldton',
#  'tual',
#  'chikoy',
#  'butaritari',
#  'ceanu mare',
#  'palu',
#  'hofn',
#  'xingyi',
#  'grand river south east',
#  'balkhash',
#  'avarua',
#  'mys shmidta',
#  'datong',
#  'carutapera',
#  'cidreira',
#  'nanortalik',
#  'zlitan',
#  'sungaipenuh',
#  'bodegraven',
#  'edmundston',
#  'constitucion',
#  'toamasina',
#  'hurricane',
#  'jibuti',
#  'hami',
#  'codrington',
#  'greenwood',
#  'vardo',
#  'port-de-paix',
#  'hervey bay',
#  'broome',
#  'yuza',
#  'turayf',
#  'east london',
#  'la baule-escoublac',
#  'iralaya',
#  'vestmannaeyjar',
#  'alta floresta',
#  'ancud',
#  'qaqortoq',
#  'westerland',
#  'severo-kurilsk',
#  'nizwa',
#  'hendijan',
#  'nkoteng',
#  'fukue',
#  'catuday',
#  'kysyl-syr',
#  'aripuana',
#  'yinchuan',
#  'luba',
#  'bengkulu',
#  'anadyr',
#  'grande riviere du nord',
#  'kodinsk',
#  'saint-augustin',
#  'chernyshevskiy',
#  'alihe',
#  'kaeo',
#  'iskateley',
#  'nouakchott',
#  'kokopo',
#  'yellowknife',
#  'imbituba',
#  'tura',
#  'souillac',
#  'ahuimanu',
#  'pochutla',
#  'yumen',
#  'mahebourg',
#  'arraial do cabo',
#  'faya',
#  'agadez',
#  'mildura',
#  'phetchabun',
#  'dubreka',
#  'zeya',
#  'namibe',
#  'beisfjord',
#  'along',
#  'bernal',
#  'leningradskiy',
#  'buala',
#  'vatutinki',
#  'phek',
#  'ormara',
#  'sovetskiy',
#  'veracruz',
#  'tsienyane',
#  'roma',
#  'severo-yeniseyskiy',
#  'plettenberg bay',
#  'kruisfontein',
#  'ji-parana',
#  'henties bay',
#  'bathsheba',
#  'paytug',
#  'sorland',
#  'chokurdakh',
#  'isangel',
#  'amderma',
#  'nizhnevartovsk',
#  'conceicao da barra',
#  'sao gabriel da cachoeira',
#  'sechura',
#  'salisbury',
#  'bereda',
#  'bulungu',
#  'tomatlan',
#  'concarneau',
#  'abay',
#  'palabuhanratu',
#  'kavieng',
#  'ahipara',
#  'luderitz',
#  'pangai',
#  'razole',
#  'la paz',
#  'gravdal',
#  'santa maria',
#  'iqaluit',
#  'waddan',
#  'hailar',
#  'skjervoy',
#  'saint-joseph',
#  'tutoia',
#  'baoqing',
#  'gamba',
#  'puerto del rosario',
#  'vasilkovo',
#  'blackfoot',
#  'lillooet',
#  'cabo san lucas',
#  'mar del plata',
#  'juneau',
#  'mabaruma',
#  'aflu',
#  'taoudenni',
#  'aguadilla',
#  'talnakh',
#  'te anau',
#  'gdynia',
#  'russkaya polyana',
#  'bandarban',
#  'lompoc',
#  'ust-nera',
#  'zaysan',
#  'laela',
#  'mahadday weyne',
#  'beoumi',
#  'otradnoye',
#  'izumo',
#  'riyadh',
#  'mitsamiouli',
#  'sri aman',
#  'ithaca',
#  'fillan',
#  'port macquarie',
#  'sterling',
#  'guerrero negro',
#  'korla',
#  'victoria',
#  'fortuna',
#  'najran',
#  'sao filipe',
#  'lata',
#  'honiara',
#  'walvis bay',
#  'saint-pierre',
#  'luis correia',
#  'axim',
#  'ronne',
#  'oktyabrskiy',
#  'soyo',
#  'moussoro',
#  'murray bridge',
#  'gorontalo',
#  'beian',
#  'yar-sale',
#  'siderno',
#  'saint-michel-des-saints',
#  'havre-saint-pierre',
#  'naryan-mar',
#  'camacupa',
#  'ossora',
#  'necochea',
#  'mount gambier',
#  'north platte',
#  'buin',
#  'brae',
#  'azimur',
#  'vengerovo',
#  'san cristobal',
#  'avesta',
#  'pueblo',
#  'makakilo city',
#  'adrar',
#  'rocha',
#  'seguin',
#  'karkaralinsk',
#  'ongandjera',
#  'fairbanks',
#  'katangli',
#  'noumea',
#  'nisia floresta',
#  'georgetown',
#  'yukon',
#  'kargasok',
#  'krasnoselkup',
#  'baculin',
#  'awjilah',
#  'alice town',
#  'lagoa',
#  'waipawa',
#  'barawe',
#  'helena',
#  'khandyga',
#  'bac giang',
#  'hienghene',
#  'asau',
#  'ustyuzhna',
#  'celestun',
#  'lasa',
#  'udomlya',
#  'esfarayen',
#  'puerto penasco',
#  'basoko',
#  'sentyabrskiy',
#  'bartica',
#  'monte cristi',
#  'miragoane',
#  'orbetello',
#  'yabrud',
#  'san patricio',
#  'kedrovyy',
#  'jinchang',
#  'coquimbo',
#  'sankt georgen',
#  'los llanos de aridane',
#  'orumiyeh',
#  'kimberley',
#  'brisbane',
#  'isla mujeres',
#  'jambi',
#  'ust-tsilma',
#  'urucara',
#  'beringovskiy',
#  'vila velha',
#  'antofagasta',
#  'ranong',
#  'shimoda',
#  'vanimo',
#  'arlit',
#  'sabzevar',
#  'maunabo',
#  'torbay',
#  'tres arroyos',
#  'esperance',
#  'ijaki',
#  'irituia',
#  'sinnamary',
#  'honolulu',
#  'kalyazin',
#  'calabozo',
#  'khurba',
#  'istisu',
#  'bikin',
#  'osorno',
#  'ambon',
#  'viligili',
#  'luangwa',
#  'ca mau',
#  'oshkosh',
#  'road town',
#  'tabuk',
#  'bowen',
#  'ornskoldsvik',
#  'zyryanovsk',
#  'estelle',
#  'ibb',
#  'bayan',
#  'takaka',
#  'edea',
#  'buqayq',
#  'verkhnyaya inta',
#  'tuatapere',
#  'husavik',
#  'barbar',
#  'oranjemund',
#  'meadow lake',
#  'namatanai',
#  'katherine',
#  'batagay',
#  'nantucket',
#  'zelenogradsk',
#  'ostersund',
#  'half moon bay',
#  'port augusta',
#  'galveston',
#  'santa rosa',
#  'sherbakul',
#  'carballo',
#  'rio gallegos',
#  'birakan',
#  'cayenne',
#  'mbekenyera',
#  'ust-kulom',
#  'caranavi',
#  'gigmoto',
#  'gorbatov',
#  'yamada',
#  'bafra',
#  'hoegaarden',
#  'panubigan',
#  'mrirt',
#  'bay city',
#  'le portel',
#  'guilin',
#  'gazanjyk',
#  'jacareacanga',
#  'tumannyy',
#  'nemuro',
#  'maragogi',
#  'custoias',
#  'san clemente',
#  'aksu',
#  'mnogovershinnyy',
#  'raudeberg',
#  'nahan',
#  'klaksvik',
#  'harper',
#  'bouna',
#  'itoman',
#  'winnemucca',
#  'vila franca do campo',
#  'aswan',
#  'olafsvik',
#  'whitehorse',
#  'tidore',
#  'san juan',
#  'rumuruti',
#  'callaway',
#  'bamenda',
#  'toliary',
#  'orsha',
#  'kathmandu',
#  'araouane',
#  'sao paulo de olivenca',
#  'pandan',
#  'kalangala',
#  'rutland',
#  'zorgo',
#  'polyarnyy',
#  'hobyo',
#  'zalantun',
#  'san julian',
#  'samarai',
#  'sandy point',
#  'katsuura',
#  'alta gracia',
#  'jaisalmer',
#  'ulladulla',
#  'tilichiki',
#  'kiruna',
#  'negele',
#  'pine bluff',
#  'vostok',
#  'kudahuvadhoo',
#  'boa vista',
#  'avera',
#  'port lincoln',
#  'zapolyarnyy',
#  'dingle',
#  'fulitun',
#  'genhe',
#  'portland',
#  'san quintin',
#  'saleaula',
#  'bakchar',
#  'ghanzi',
#  'thinadhoo',
#  'wilson',
#  'praya',
#  'ternate',
#  'huangchuan',
#  'porto velho',
#  'tautira',
#  'dongli',
#  'kautokeino',
#  'puerto baquerizo moreno',
#  'ishigaki',
#  'gazli',
#  'pemberton',
#  'altamont',
#  'mana',
#  'hay river',
#  'hokitika',
#  'vredendal',
#  'gourcy',
#  'ginir',
#  'den helder',
#  'mount isa',
#  'griffith',
#  'warrington',
#  'port hueneme',
#  'acarau',
#  'svetlogorsk',
#  'mergui',
#  'hrodna',
#  'tungor',
#  'santa ines',
#  'poopo',
#  'el faiyum',
#  'phalaborwa',
#  'petropavlovsk-kamchatskiy',
#  'boca do acre',
#  'lewistown',
#  'epe',
#  'gilgit',
#  'chagda',
#  'abnub',
#  'trairi',
#  'pitimbu',
#  'maghama',
#  'huadian',
#  'marsh harbour',
#  'tapaua',
#  'tsiroanomandidy',
#  'silver city',
#  'lakhnadon',
#  'paradwip',
#  'a',
#  'barreirinhas',
#  'prince rupert',
#  'talas',
#  'arukula',
#  'yeniseysk',
#  'chapais',
#  'velikodvorskiy',
#  'dickinson',
#  'rungata',
#  'aguilas',
#  'abancay',
#  'sug-aksy',
#  'san luis',
#  'makat',
#  'mayskiy',
#  'tessalit',
#  'arrecife',
#  'chake chake',
#  'makung',
#  'svetlaya',
#  'kijang',
#  'muswellbrook',
#  'tuy hoa',
#  'tendo',
#  'caxias',
#  'zachagansk',
#  'staryy nadym',
#  'iaciara',
#  'colonesti',
#  'inirida',
#  'babstovo',
#  'algeciras',
#  'nadym',
#  'devyatka',
#  'puerto colombia',
#  'wahran',
#  'wabrzezno',
#  'hearst',
#  'senneterre',
#  'nuuk',
#  'pochinok',
#  'mayo',
#  'whitley bay',
#  'halifax',
#  'minna',
#  'bac lieu',
#  'san vicente',
#  'pingchen',
#  'ust-maya',
#  'lucapa',
#  'bambanglipuro',
#  'barcelos',
#  'kaihua',
#  'tiruvottiyur',
#  'bastia',
#  'chodavaram',
#  'paragominas',
#  'general roca',
#  'richards bay',
#  'drummondville',
#  'ketchikan',
#  'sabang',
#  'chokwe',
#  'houlung',
#  'san-pedro',
#  'bandarbeyla',
#  'tigil',
#  'huarmey',
#  'doha',
#  'mitu',
#  'vanavara',
#  'alappuzha',
#  'cabedelo',
#  'maniitsoq',
#  'boyolangu',
#  'mogadishu',
#  'rosetta',
#  'pacifica',
#  'yaan',
#  'hamilton',
#  'kendari',
#  'narasannapeta',
#  'mooi river',
#  'satitoa',
#  'sobolevo',
#  'eureka',
#  'toulepleu',
#  'uruzgan',
#  'laguna',
#  'shanghai',
#  'jijiga',
#  'mullaitivu',
#  'lahad datu',
#  'naze',
#  'chase',
#  'nakamura',
#  'denpasar',
#  'acandi',
#  'marovoay',
#  'lolua',
#  'lohja',
#  'biloxi',
#  'bose',
#  'hovd',
#  'manaus',
#  'adre',
#  'babanusah',
#  'mustasaari',
#  'ndende',
#  'byron bay',
#  'arinos',
#  'shelburne',
#  'soubre',
#  'patrocinio',
#  'ponta delgada',
#  'pachino',
#  'ruatoria',
#  'grand gaube',
#  'abalak',
#  'vryburg',
#  'cap malheureux',
#  'kisangani',
#  'herat',
#  'mbabane',
#  'solnechnyy',
#  'porto novo',
#  'nanakuli',
#  'launceston',
#  'banff',
#  'acajutla',
#  'isahaya',
#  'tabou',
#  'melito di porto salvo',
#  'vaitupu',
#  'shimanovsk',
#  'salamiyah',
#  'lalsot',
#  'burica',
#  'naftah',
#  'bibiani',
#  'san jeronimo',
#  'qeshm',
#  'yemelyanovo',
#  'khandbari',
#  'loralai',
#  'bay roberts',
#  'juelsminde',
#  'tambovka',
#  'luceville']

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_description = city_weather["weather"][0]["description"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description" : city_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 16 | barrow
# Processing Record 2 of Set 16 | faanui
# Processing Record 3 of Set 16 | rikitea
# Processing Record 4 of Set 16 | carauari
# Processing Record 5 of Set 16 | sao joao da barra
# Processing Record 6 of Set 16 | saldanha
# Processing Record 7 of Set 16 | taganak
# Processing Record 8 of Set 16 | punta arenas
# Processing Record 9 of Set 16 | marshall
# Processing Record 10 of Set 16 | kaitangata
# Processing Record 11 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 16 | saint-philippe
# Processing Record 13 of Set 16 | norman wells
# Processing Record 14 of Set 16 | atar
# Processing Record 15 of Set 16 | kharan
# Processing Record 16 of Set 16 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 16 | tuktoyaktuk
# Processing Record 18 of Set 16 | manavalakurichi
# Processing Record 19 of Set 16 | hithadhoo
# Processing Record 20 of Set 16 | jalu
# Processing Record 21 of Set 16 | wulanhaote
# City not found. Skipping...
# Processing Record 22 of Set 16 | haines junction
# Processing Record 23 of Set 16 | bethel
# Processing Record 24 of Set 16 | bluff
# Processing Record 25 of Set 16 | saint george
# Processing Record 26 of Set 16 | narsaq
# Processing Record 27 of Set 16 | saskylakh
# Processing Record 28 of Set 16 | nalut
# Processing Record 29 of Set 16 | nikolskoye
# Processing Record 30 of Set 16 | new norfolk
# Processing Record 31 of Set 16 | ribeira grande
# Processing Record 32 of Set 16 | kholtoson
# Processing Record 33 of Set 16 | palmer
# Processing Record 34 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 16 | saint-georges
# Processing Record 36 of Set 16 | rawson
# Processing Record 37 of Set 16 | ostrovnoy
# Processing Record 38 of Set 16 | jamestown
# Processing Record 39 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 16 | englehart
# Processing Record 41 of Set 16 | sao joao de pirabas
# Processing Record 42 of Set 16 | clyde river
# Processing Record 43 of Set 16 | kodiak
# Processing Record 44 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 16 | tasiilaq
# Processing Record 46 of Set 16 | la ronge
# Processing Record 47 of Set 16 | mataura
# Processing Record 48 of Set 16 | cape town
# Processing Record 49 of Set 16 | ucluelet
# Processing Record 50 of Set 16 | preeceville
# Processing Record 1 of Set 17 | nelson bay
# Processing Record 2 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 17 | evensk
# Processing Record 4 of Set 17 | pimentel
# Processing Record 5 of Set 17 | khonuu
# City not found. Skipping...
# Processing Record 6 of Set 17 | pevek
# Processing Record 7 of Set 17 | apostolove
# Processing Record 8 of Set 17 | port elizabeth
# Processing Record 9 of Set 17 | ponta do sol
# Processing Record 10 of Set 17 | tiksi
# Processing Record 11 of Set 17 | albany
# Processing Record 12 of Set 17 | date
# Processing Record 13 of Set 17 | matveyevka
# Processing Record 14 of Set 17 | karasjok
# Processing Record 15 of Set 17 | provideniya
# Processing Record 16 of Set 17 | teeli
# Processing Record 17 of Set 17 | pontal do parana
# Processing Record 18 of Set 17 | zhangye
# Processing Record 19 of Set 17 | waingapu
# Processing Record 20 of Set 17 | cumaribo
# City not found. Skipping...
# Processing Record 21 of Set 17 | pangnirtung
# Processing Record 22 of Set 17 | nhulunbuy
# Processing Record 23 of Set 17 | jonesboro
# Processing Record 24 of Set 17 | lavrentiya
# Processing Record 25 of Set 17 | chillan
# Processing Record 26 of Set 17 | aklavik
# Processing Record 27 of Set 17 | nishihara
# Processing Record 28 of Set 17 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 17 | bend
# Processing Record 30 of Set 17 | umm kaddadah
# Processing Record 31 of Set 17 | angra
# City not found. Skipping...
# Processing Record 32 of Set 17 | comodoro rivadavia
# Processing Record 33 of Set 17 | hilo
# Processing Record 34 of Set 17 | koumac
# Processing Record 35 of Set 17 | tornio
# Processing Record 36 of Set 17 | atuona
# Processing Record 37 of Set 17 | tongliao
# Processing Record 38 of Set 17 | ushuaia
# Processing Record 39 of Set 17 | thompson
# Processing Record 40 of Set 17 | katha
# City not found. Skipping...
# Processing Record 41 of Set 17 | bilibino
# Processing Record 42 of Set 17 | yerbogachen
# Processing Record 43 of Set 17 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 17 | caravelas
# Processing Record 45 of Set 17 | busselton
# Processing Record 46 of Set 17 | sola
# Processing Record 47 of Set 17 | kanlagay
# Processing Record 48 of Set 17 | arantangi
# Processing Record 49 of Set 17 | saundatti yellamma
# City not found. Skipping...
# Processing Record 50 of Set 17 | chuy
# Processing Record 1 of Set 18 | castro
# Processing Record 2 of Set 18 | calvia
# Processing Record 3 of Set 18 | pocone
# Processing Record 4 of Set 18 | lebu
# Processing Record 5 of Set 18 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 18 | yulara
# Processing Record 7 of Set 18 | praia da vitoria
# Processing Record 8 of Set 18 | banda aceh
# Processing Record 9 of Set 18 | kenora
# Processing Record 10 of Set 18 | cherskiy
# Processing Record 11 of Set 18 | alofi
# Processing Record 12 of Set 18 | ust-kuyga
# Processing Record 13 of Set 18 | lalomanu
# City not found. Skipping...
# Processing Record 14 of Set 18 | trelew
# Processing Record 15 of Set 18 | seymchan
# Processing Record 16 of Set 18 | brazzaville
# Processing Record 17 of Set 18 | aksarka
# Processing Record 18 of Set 18 | havre
# Processing Record 19 of Set 18 | harrisonville
# Processing Record 20 of Set 18 | kahului
# Processing Record 21 of Set 18 | vaini
# Processing Record 22 of Set 18 | konstantinovka
# Processing Record 23 of Set 18 | murgab
# Processing Record 24 of Set 18 | poso
# Processing Record 25 of Set 18 | bambous virieux
# Processing Record 26 of Set 18 | maraa
# Processing Record 27 of Set 18 | puerto escondido
# Processing Record 28 of Set 18 | marawi
# Processing Record 29 of Set 18 | muros
# Processing Record 30 of Set 18 | qaanaaq
# Processing Record 31 of Set 18 | anacortes
# Processing Record 32 of Set 18 | saint-louis
# Processing Record 33 of Set 18 | makarov
# Processing Record 34 of Set 18 | kapaa
# Processing Record 35 of Set 18 | tarakan
# Processing Record 36 of Set 18 | nauchnyy gorodok
# Processing Record 37 of Set 18 | neuquen
# Processing Record 38 of Set 18 | cururupu
# Processing Record 39 of Set 18 | kavaratti
# Processing Record 40 of Set 18 | khatanga
# Processing Record 41 of Set 18 | magistralnyy
# Processing Record 42 of Set 18 | mangan
# Processing Record 43 of Set 18 | zaporizhzhya
# Processing Record 44 of Set 18 | puerto ayora
# Processing Record 45 of Set 18 | airai
# Processing Record 46 of Set 18 | jiuquan
# Processing Record 47 of Set 18 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 18 | aykhal
# Processing Record 49 of Set 18 | coahuayana
# Processing Record 50 of Set 18 | alugan
# Processing Record 1 of Set 19 | port hedland
# Processing Record 2 of Set 19 | longyearbyen
# Processing Record 3 of Set 19 | himora
# City not found. Skipping...
# Processing Record 4 of Set 19 | biloela
# Processing Record 5 of Set 19 | sur
# Processing Record 6 of Set 19 | costinesti
# Processing Record 7 of Set 19 | nador
# Processing Record 8 of Set 19 | turukhansk
# Processing Record 9 of Set 19 | flinders
# Processing Record 10 of Set 19 | hanzhong
# Processing Record 11 of Set 19 | hobart
# Processing Record 12 of Set 19 | sioux lookout
# Processing Record 13 of Set 19 | sisimiut
# Processing Record 14 of Set 19 | taltal
# Processing Record 15 of Set 19 | kindu
# Processing Record 16 of Set 19 | morlaix
# Processing Record 17 of Set 19 | north bend
# Processing Record 18 of Set 19 | velyka lepetykha
# Processing Record 19 of Set 19 | la orilla
# Processing Record 20 of Set 19 | cravo norte
# Processing Record 21 of Set 19 | pag
# Processing Record 22 of Set 19 | olinda
# Processing Record 23 of Set 19 | kostomuksha
# Processing Record 24 of Set 19 | ilebo
# Processing Record 25 of Set 19 | ilulissat
# Processing Record 26 of Set 19 | komsomolskiy
# Processing Record 27 of Set 19 | hambantota
# Processing Record 28 of Set 19 | sitka
# Processing Record 29 of Set 19 | sangar
# Processing Record 30 of Set 19 | carnarvon
# Processing Record 31 of Set 19 | rio tuba
# Processing Record 32 of Set 19 | luau
# Processing Record 33 of Set 19 | hasaki
# Processing Record 34 of Set 19 | berlevag
# Processing Record 35 of Set 19 | presidencia roque saenz pena
# Processing Record 36 of Set 19 | victor harbor
# Processing Record 37 of Set 19 | solovetskiy
# City not found. Skipping...
# Processing Record 38 of Set 19 | port alfred
# Processing Record 39 of Set 19 | marzuq
# Processing Record 40 of Set 19 | lorengau
# Processing Record 41 of Set 19 | nome
# Processing Record 42 of Set 19 | hermanus
# Processing Record 43 of Set 19 | salalah
# Processing Record 44 of Set 19 | edd
# Processing Record 45 of Set 19 | pisco
# Processing Record 46 of Set 19 | teguise
# Processing Record 47 of Set 19 | bredasdorp
# Processing Record 48 of Set 19 | mackay
# Processing Record 49 of Set 19 | belaya gora
# Processing Record 50 of Set 19 | puerto el triunfo
# Processing Record 1 of Set 20 | upernavik
# Processing Record 2 of Set 20 | manokwari
# Processing Record 3 of Set 20 | dikson
# Processing Record 4 of Set 20 | geraldton
# Processing Record 5 of Set 20 | tual
# Processing Record 6 of Set 20 | chikoy
# City not found. Skipping...
# Processing Record 7 of Set 20 | butaritari
# Processing Record 8 of Set 20 | ceanu mare
# Processing Record 9 of Set 20 | palu
# Processing Record 10 of Set 20 | hofn
# Processing Record 11 of Set 20 | xingyi
# Processing Record 12 of Set 20 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 20 | balkhash
# Processing Record 14 of Set 20 | avarua
# Processing Record 15 of Set 20 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 20 | datong
# Processing Record 17 of Set 20 | carutapera
# Processing Record 18 of Set 20 | cidreira
# Processing Record 19 of Set 20 | nanortalik
# Processing Record 20 of Set 20 | zlitan
# Processing Record 21 of Set 20 | sungaipenuh
# Processing Record 22 of Set 20 | bodegraven
# Processing Record 23 of Set 20 | edmundston
# Processing Record 24 of Set 20 | constitucion
# Processing Record 25 of Set 20 | toamasina
# Processing Record 26 of Set 20 | hurricane
# Processing Record 27 of Set 20 | jibuti
# Processing Record 28 of Set 20 | hami
# Processing Record 29 of Set 20 | codrington
# Processing Record 30 of Set 20 | greenwood
# Processing Record 31 of Set 20 | vardo
# Processing Record 32 of Set 20 | port-de-paix
# City not found. Skipping...
# Processing Record 33 of Set 20 | hervey bay
# Processing Record 34 of Set 20 | broome
# Processing Record 35 of Set 20 | yuza
# Processing Record 36 of Set 20 | turayf
# Processing Record 37 of Set 20 | east london
# Processing Record 38 of Set 20 | la baule-escoublac
# Processing Record 39 of Set 20 | iralaya
# Processing Record 40 of Set 20 | vestmannaeyjar
# Processing Record 41 of Set 20 | alta floresta
# Processing Record 42 of Set 20 | ancud
# Processing Record 43 of Set 20 | qaqortoq
# Processing Record 44 of Set 20 | westerland
# Processing Record 45 of Set 20 | severo-kurilsk
# Processing Record 46 of Set 20 | nizwa
# Processing Record 47 of Set 20 | hendijan
# City not found. Skipping...
# Processing Record 48 of Set 20 | nkoteng
# Processing Record 49 of Set 20 | fukue
# Processing Record 50 of Set 20 | catuday
# Processing Record 1 of Set 21 | kysyl-syr
# Processing Record 2 of Set 21 | aripuana
# Processing Record 3 of Set 21 | yinchuan
# Processing Record 4 of Set 21 | luba
# Processing Record 5 of Set 21 | bengkulu
# Processing Record 6 of Set 21 | anadyr
# Processing Record 7 of Set 21 | grande riviere du nord
# Processing Record 8 of Set 21 | kodinsk
# Processing Record 9 of Set 21 | saint-augustin
# Processing Record 10 of Set 21 | chernyshevskiy
# Processing Record 11 of Set 21 | alihe
# Processing Record 12 of Set 21 | kaeo
# Processing Record 13 of Set 21 | iskateley
# Processing Record 14 of Set 21 | nouakchott
# Processing Record 15 of Set 21 | kokopo
# Processing Record 16 of Set 21 | yellowknife
# Processing Record 17 of Set 21 | imbituba
# Processing Record 18 of Set 21 | tura
# Processing Record 19 of Set 21 | souillac
# Processing Record 20 of Set 21 | ahuimanu
# Processing Record 21 of Set 21 | pochutla
# Processing Record 22 of Set 21 | yumen
# Processing Record 23 of Set 21 | mahebourg
# Processing Record 24 of Set 21 | arraial do cabo
# Processing Record 25 of Set 21 | faya
# Processing Record 26 of Set 21 | agadez
# Processing Record 27 of Set 21 | mildura
# Processing Record 28 of Set 21 | phetchabun
# Processing Record 29 of Set 21 | dubreka
# Processing Record 30 of Set 21 | zeya
# Processing Record 31 of Set 21 | namibe
# Processing Record 32 of Set 21 | beisfjord
# Processing Record 33 of Set 21 | along
# Processing Record 34 of Set 21 | bernal
# Processing Record 35 of Set 21 | leningradskiy
# Processing Record 36 of Set 21 | buala
# Processing Record 37 of Set 21 | vatutinki
# Processing Record 38 of Set 21 | phek
# Processing Record 39 of Set 21 | ormara
# Processing Record 40 of Set 21 | sovetskiy
# Processing Record 41 of Set 21 | veracruz
# Processing Record 42 of Set 21 | tsienyane
# City not found. Skipping...
# Processing Record 43 of Set 21 | roma
# Processing Record 44 of Set 21 | severo-yeniseyskiy
# Processing Record 45 of Set 21 | plettenberg bay
# Processing Record 46 of Set 21 | kruisfontein
# Processing Record 47 of Set 21 | ji-parana
# City not found. Skipping...
# Processing Record 48 of Set 21 | henties bay
# Processing Record 49 of Set 21 | bathsheba
# Processing Record 50 of Set 21 | paytug
# City not found. Skipping...
# Processing Record 1 of Set 22 | sorland
# Processing Record 2 of Set 22 | chokurdakh
# Processing Record 3 of Set 22 | isangel
# Processing Record 4 of Set 22 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 22 | nizhnevartovsk
# Processing Record 6 of Set 22 | conceicao da barra
# Processing Record 7 of Set 22 | sao gabriel da cachoeira
# Processing Record 8 of Set 22 | sechura
# Processing Record 9 of Set 22 | salisbury
# Processing Record 10 of Set 22 | bereda
# Processing Record 11 of Set 22 | bulungu
# Processing Record 12 of Set 22 | tomatlan
# Processing Record 13 of Set 22 | concarneau
# Processing Record 14 of Set 22 | abay
# Processing Record 15 of Set 22 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 22 | kavieng
# Processing Record 17 of Set 22 | ahipara
# Processing Record 18 of Set 22 | luderitz
# Processing Record 19 of Set 22 | pangai
# Processing Record 20 of Set 22 | razole
# Processing Record 21 of Set 22 | la paz
# Processing Record 22 of Set 22 | gravdal
# Processing Record 23 of Set 22 | santa maria
# Processing Record 24 of Set 22 | iqaluit
# Processing Record 25 of Set 22 | waddan
# Processing Record 26 of Set 22 | hailar
# Processing Record 27 of Set 22 | skjervoy
# Processing Record 28 of Set 22 | saint-joseph
# Processing Record 29 of Set 22 | tutoia
# Processing Record 30 of Set 22 | baoqing
# Processing Record 31 of Set 22 | gamba
# Processing Record 32 of Set 22 | puerto del rosario
# Processing Record 33 of Set 22 | vasilkovo
# City not found. Skipping...
# Processing Record 34 of Set 22 | blackfoot
# Processing Record 35 of Set 22 | lillooet
# Processing Record 36 of Set 22 | cabo san lucas
# Processing Record 37 of Set 22 | mar del plata
# Processing Record 38 of Set 22 | juneau
# Processing Record 39 of Set 22 | mabaruma
# Processing Record 40 of Set 22 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 22 | taoudenni
# Processing Record 42 of Set 22 | aguadilla
# Processing Record 43 of Set 22 | talnakh
# Processing Record 44 of Set 22 | te anau
# Processing Record 45 of Set 22 | gdynia
# Processing Record 46 of Set 22 | russkaya polyana
# Processing Record 47 of Set 22 | bandarban
# Processing Record 48 of Set 22 | lompoc
# Processing Record 49 of Set 22 | ust-nera
# Processing Record 50 of Set 22 | zaysan
# Processing Record 1 of Set 23 | laela
# Processing Record 2 of Set 23 | mahadday weyne
# City not found. Skipping...
# Processing Record 3 of Set 23 | beoumi
# Processing Record 4 of Set 23 | otradnoye
# Processing Record 5 of Set 23 | izumo
# Processing Record 6 of Set 23 | riyadh
# Processing Record 7 of Set 23 | mitsamiouli
# Processing Record 8 of Set 23 | sri aman
# Processing Record 9 of Set 23 | ithaca
# Processing Record 10 of Set 23 | fillan
# Processing Record 11 of Set 23 | port macquarie
# Processing Record 12 of Set 23 | sterling
# Processing Record 13 of Set 23 | guerrero negro
# Processing Record 14 of Set 23 | korla
# Processing Record 15 of Set 23 | victoria
# Processing Record 16 of Set 23 | fortuna
# Processing Record 17 of Set 23 | najran
# Processing Record 18 of Set 23 | sao filipe
# Processing Record 19 of Set 23 | lata
# Processing Record 20 of Set 23 | honiara
# Processing Record 21 of Set 23 | walvis bay
# Processing Record 22 of Set 23 | saint-pierre
# Processing Record 23 of Set 23 | luis correia
# Processing Record 24 of Set 23 | axim
# Processing Record 25 of Set 23 | ronne
# Processing Record 26 of Set 23 | oktyabrskiy
# Processing Record 27 of Set 23 | soyo
# Processing Record 28 of Set 23 | moussoro
# Processing Record 29 of Set 23 | murray bridge
# Processing Record 30 of Set 23 | gorontalo
# Processing Record 31 of Set 23 | beian
# Processing Record 32 of Set 23 | yar-sale
# Processing Record 33 of Set 23 | siderno
# Processing Record 34 of Set 23 | saint-michel-des-saints
# Processing Record 35 of Set 23 | havre-saint-pierre
# Processing Record 36 of Set 23 | naryan-mar
# Processing Record 37 of Set 23 | camacupa
# Processing Record 38 of Set 23 | ossora
# Processing Record 39 of Set 23 | necochea
# Processing Record 40 of Set 23 | mount gambier
# Processing Record 41 of Set 23 | north platte
# Processing Record 42 of Set 23 | buin
# Processing Record 43 of Set 23 | brae
# Processing Record 44 of Set 23 | azimur
# City not found. Skipping...
# Processing Record 45 of Set 23 | vengerovo
# Processing Record 46 of Set 23 | san cristobal
# Processing Record 47 of Set 23 | avesta
# Processing Record 48 of Set 23 | pueblo
# Processing Record 49 of Set 23 | makakilo city
# Processing Record 50 of Set 23 | adrar
# Processing Record 1 of Set 24 | rocha
# Processing Record 2 of Set 24 | seguin
# Processing Record 3 of Set 24 | karkaralinsk
# City not found. Skipping...
# Processing Record 4 of Set 24 | ongandjera
# Processing Record 5 of Set 24 | fairbanks
# Processing Record 6 of Set 24 | katangli
# Processing Record 7 of Set 24 | noumea
# Processing Record 8 of Set 24 | nisia floresta
# Processing Record 9 of Set 24 | georgetown
# Processing Record 10 of Set 24 | yukon
# Processing Record 11 of Set 24 | kargasok
# Processing Record 12 of Set 24 | krasnoselkup
# Processing Record 13 of Set 24 | baculin
# Processing Record 14 of Set 24 | awjilah
# Processing Record 15 of Set 24 | alice town
# Processing Record 16 of Set 24 | lagoa
# Processing Record 17 of Set 24 | waipawa
# Processing Record 18 of Set 24 | barawe
# City not found. Skipping...
# Processing Record 19 of Set 24 | helena
# Processing Record 20 of Set 24 | khandyga
# Processing Record 21 of Set 24 | bac giang
# Processing Record 22 of Set 24 | hienghene
# Processing Record 23 of Set 24 | asau
# Processing Record 24 of Set 24 | ustyuzhna
# Processing Record 25 of Set 24 | celestun
# Processing Record 26 of Set 24 | lasa
# Processing Record 27 of Set 24 | udomlya
# Processing Record 28 of Set 24 | esfarayen
# Processing Record 29 of Set 24 | puerto penasco
# Processing Record 30 of Set 24 | basoko
# Processing Record 31 of Set 24 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 24 | bartica
# Processing Record 33 of Set 24 | monte cristi
# City not found. Skipping...
# Processing Record 34 of Set 24 | miragoane
# Processing Record 35 of Set 24 | orbetello
# Processing Record 36 of Set 24 | yabrud
# Processing Record 37 of Set 24 | san patricio
# Processing Record 38 of Set 24 | kedrovyy
# Processing Record 39 of Set 24 | jinchang
# Processing Record 40 of Set 24 | coquimbo
# Processing Record 41 of Set 24 | sankt georgen
# Processing Record 42 of Set 24 | los llanos de aridane
# Processing Record 43 of Set 24 | orumiyeh
# Processing Record 44 of Set 24 | kimberley
# Processing Record 45 of Set 24 | brisbane
# Processing Record 46 of Set 24 | isla mujeres
# Processing Record 47 of Set 24 | jambi
# Processing Record 48 of Set 24 | ust-tsilma
# Processing Record 49 of Set 24 | urucara
# Processing Record 50 of Set 24 | beringovskiy
# Processing Record 1 of Set 25 | vila velha
# Processing Record 2 of Set 25 | antofagasta
# Processing Record 3 of Set 25 | ranong
# Processing Record 4 of Set 25 | shimoda
# Processing Record 5 of Set 25 | vanimo
# Processing Record 6 of Set 25 | arlit
# Processing Record 7 of Set 25 | sabzevar
# Processing Record 8 of Set 25 | maunabo
# Processing Record 9 of Set 25 | torbay
# Processing Record 10 of Set 25 | tres arroyos
# Processing Record 11 of Set 25 | esperance
# Processing Record 12 of Set 25 | ijaki
# City not found. Skipping...
# Processing Record 13 of Set 25 | irituia
# Processing Record 14 of Set 25 | sinnamary
# Processing Record 15 of Set 25 | honolulu
# Processing Record 16 of Set 25 | kalyazin
# Processing Record 17 of Set 25 | calabozo
# Processing Record 18 of Set 25 | khurba
# Processing Record 19 of Set 25 | istisu
# Processing Record 20 of Set 25 | bikin
# Processing Record 21 of Set 25 | osorno
# Processing Record 22 of Set 25 | ambon
# Processing Record 23 of Set 25 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 25 | luangwa
# Processing Record 25 of Set 25 | ca mau
# Processing Record 26 of Set 25 | oshkosh
# Processing Record 27 of Set 25 | road town
# Processing Record 28 of Set 25 | tabuk
# Processing Record 29 of Set 25 | bowen
# Processing Record 30 of Set 25 | ornskoldsvik
# Processing Record 31 of Set 25 | zyryanovsk
# Processing Record 32 of Set 25 | estelle
# Processing Record 33 of Set 25 | ibb
# Processing Record 34 of Set 25 | bayan
# Processing Record 35 of Set 25 | takaka
# Processing Record 36 of Set 25 | edea
# Processing Record 37 of Set 25 | buqayq
# City not found. Skipping...
# Processing Record 38 of Set 25 | verkhnyaya inta
# Processing Record 39 of Set 25 | tuatapere
# Processing Record 40 of Set 25 | husavik
# Processing Record 41 of Set 25 | barbar
# City not found. Skipping...
# Processing Record 42 of Set 25 | oranjemund
# Processing Record 43 of Set 25 | meadow lake
# Processing Record 44 of Set 25 | namatanai
# Processing Record 45 of Set 25 | katherine
# Processing Record 46 of Set 25 | batagay
# Processing Record 47 of Set 25 | nantucket
# Processing Record 48 of Set 25 | zelenogradsk
# Processing Record 49 of Set 25 | ostersund
# Processing Record 50 of Set 25 | half moon bay
# Processing Record 1 of Set 26 | port augusta
# Processing Record 2 of Set 26 | galveston
# Processing Record 3 of Set 26 | santa rosa
# Processing Record 4 of Set 26 | sherbakul
# Processing Record 5 of Set 26 | carballo
# Processing Record 6 of Set 26 | rio gallegos
# Processing Record 7 of Set 26 | birakan
# Processing Record 8 of Set 26 | cayenne
# Processing Record 9 of Set 26 | mbekenyera
# Processing Record 10 of Set 26 | ust-kulom
# Processing Record 11 of Set 26 | caranavi
# Processing Record 12 of Set 26 | gigmoto
# Processing Record 13 of Set 26 | gorbatov
# Processing Record 14 of Set 26 | yamada
# Processing Record 15 of Set 26 | bafra
# Processing Record 16 of Set 26 | hoegaarden
# Processing Record 17 of Set 26 | panubigan
# Processing Record 18 of Set 26 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 26 | bay city
# Processing Record 20 of Set 26 | le portel
# Processing Record 21 of Set 26 | guilin
# Processing Record 22 of Set 26 | gazanjyk
# Processing Record 23 of Set 26 | jacareacanga
# Processing Record 24 of Set 26 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 26 | nemuro
# Processing Record 26 of Set 26 | maragogi
# Processing Record 27 of Set 26 | custoias
# Processing Record 28 of Set 26 | san clemente
# Processing Record 29 of Set 26 | aksu
# Processing Record 30 of Set 26 | mnogovershinnyy
# Processing Record 31 of Set 26 | raudeberg
# Processing Record 32 of Set 26 | nahan
# Processing Record 33 of Set 26 | klaksvik
# Processing Record 34 of Set 26 | harper
# Processing Record 35 of Set 26 | bouna
# Processing Record 36 of Set 26 | itoman
# Processing Record 37 of Set 26 | winnemucca
# Processing Record 38 of Set 26 | vila franca do campo
# Processing Record 39 of Set 26 | aswan
# Processing Record 40 of Set 26 | olafsvik
# Processing Record 41 of Set 26 | whitehorse
# Processing Record 42 of Set 26 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 26 | san juan
# Processing Record 44 of Set 26 | rumuruti
# Processing Record 45 of Set 26 | callaway
# Processing Record 46 of Set 26 | bamenda
# Processing Record 47 of Set 26 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 26 | orsha
# Processing Record 49 of Set 26 | kathmandu
# Processing Record 50 of Set 26 | araouane
# Processing Record 1 of Set 27 | sao paulo de olivenca
# Processing Record 2 of Set 27 | pandan
# Processing Record 3 of Set 27 | kalangala
# Processing Record 4 of Set 27 | rutland
# Processing Record 5 of Set 27 | zorgo
# Processing Record 6 of Set 27 | polyarnyy
# Processing Record 7 of Set 27 | hobyo
# Processing Record 8 of Set 27 | zalantun
# Processing Record 9 of Set 27 | san julian
# Processing Record 10 of Set 27 | samarai
# Processing Record 11 of Set 27 | sandy point
# Processing Record 12 of Set 27 | katsuura
# Processing Record 13 of Set 27 | alta gracia
# Processing Record 14 of Set 27 | jaisalmer
# Processing Record 15 of Set 27 | ulladulla
# Processing Record 16 of Set 27 | tilichiki
# Processing Record 17 of Set 27 | kiruna
# Processing Record 18 of Set 27 | negele
# City not found. Skipping...
# Processing Record 19 of Set 27 | pine bluff
# Processing Record 20 of Set 27 | vostok
# Processing Record 21 of Set 27 | kudahuvadhoo
# Processing Record 22 of Set 27 | boa vista
# Processing Record 23 of Set 27 | avera
# Processing Record 24 of Set 27 | port lincoln
# Processing Record 25 of Set 27 | zapolyarnyy
# Processing Record 26 of Set 27 | dingle
# Processing Record 27 of Set 27 | fulitun
# City not found. Skipping...
# Processing Record 28 of Set 27 | genhe
# Processing Record 29 of Set 27 | portland
# Processing Record 30 of Set 27 | san quintin
# Processing Record 31 of Set 27 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 27 | bakchar
# Processing Record 33 of Set 27 | ghanzi
# Processing Record 34 of Set 27 | thinadhoo
# Processing Record 35 of Set 27 | wilson
# Processing Record 36 of Set 27 | praya
# Processing Record 37 of Set 27 | ternate
# Processing Record 38 of Set 27 | huangchuan
# Processing Record 39 of Set 27 | porto velho
# Processing Record 40 of Set 27 | tautira
# Processing Record 41 of Set 27 | dongli
# Processing Record 42 of Set 27 | kautokeino
# Processing Record 43 of Set 27 | puerto baquerizo moreno
# Processing Record 44 of Set 27 | ishigaki
# Processing Record 45 of Set 27 | gazli
# Processing Record 46 of Set 27 | pemberton
# Processing Record 47 of Set 27 | altamont
# Processing Record 48 of Set 27 | mana
# Processing Record 49 of Set 27 | hay river
# Processing Record 50 of Set 27 | hokitika
# Processing Record 1 of Set 28 | vredendal
# Processing Record 2 of Set 28 | gourcy
# Processing Record 3 of Set 28 | ginir
# Processing Record 4 of Set 28 | den helder
# Processing Record 5 of Set 28 | mount isa
# Processing Record 6 of Set 28 | griffith
# Processing Record 7 of Set 28 | warrington
# Processing Record 8 of Set 28 | port hueneme
# Processing Record 9 of Set 28 | acarau
# Processing Record 10 of Set 28 | svetlogorsk
# Processing Record 11 of Set 28 | mergui
# City not found. Skipping...
# Processing Record 12 of Set 28 | hrodna
# Processing Record 13 of Set 28 | tungor
# Processing Record 14 of Set 28 | santa ines
# Processing Record 15 of Set 28 | poopo
# Processing Record 16 of Set 28 | el faiyum
# City not found. Skipping...
# Processing Record 17 of Set 28 | phalaborwa
# Processing Record 18 of Set 28 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 28 | boca do acre
# Processing Record 20 of Set 28 | lewistown
# Processing Record 21 of Set 28 | epe
# Processing Record 22 of Set 28 | gilgit
# Processing Record 23 of Set 28 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 28 | abnub
# Processing Record 25 of Set 28 | trairi
# Processing Record 26 of Set 28 | pitimbu
# Processing Record 27 of Set 28 | maghama
# City not found. Skipping...
# Processing Record 28 of Set 28 | huadian
# Processing Record 29 of Set 28 | marsh harbour
# Processing Record 30 of Set 28 | tapaua
# City not found. Skipping...
# Processing Record 31 of Set 28 | tsiroanomandidy
# Processing Record 32 of Set 28 | silver city
# Processing Record 33 of Set 28 | lakhnadon
# Processing Record 34 of Set 28 | paradwip
# City not found. Skipping...
# Processing Record 35 of Set 28 | a
# City not found. Skipping...
# Processing Record 36 of Set 28 | barreirinhas
# Processing Record 37 of Set 28 | prince rupert
# Processing Record 38 of Set 28 | talas
# Processing Record 39 of Set 28 | arukula
# Processing Record 40 of Set 28 | yeniseysk
# Processing Record 41 of Set 28 | chapais
# Processing Record 42 of Set 28 | velikodvorskiy
# Processing Record 43 of Set 28 | dickinson
# Processing Record 44 of Set 28 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 28 | aguilas
# Processing Record 46 of Set 28 | abancay
# Processing Record 47 of Set 28 | sug-aksy
# City not found. Skipping...
# Processing Record 48 of Set 28 | san luis
# Processing Record 49 of Set 28 | makat
# Processing Record 50 of Set 28 | mayskiy
# Processing Record 1 of Set 29 | tessalit
# Processing Record 2 of Set 29 | arrecife
# Processing Record 3 of Set 29 | chake chake
# Processing Record 4 of Set 29 | makung
# City not found. Skipping...
# Processing Record 5 of Set 29 | svetlaya
# Processing Record 6 of Set 29 | kijang
# Processing Record 7 of Set 29 | muswellbrook
# Processing Record 8 of Set 29 | tuy hoa
# Processing Record 9 of Set 29 | tendo
# Processing Record 10 of Set 29 | caxias
# Processing Record 11 of Set 29 | zachagansk
# City not found. Skipping...
# Processing Record 12 of Set 29 | staryy nadym
# Processing Record 13 of Set 29 | iaciara
# Processing Record 14 of Set 29 | colonesti
# Processing Record 15 of Set 29 | inirida
# Processing Record 16 of Set 29 | babstovo
# Processing Record 17 of Set 29 | algeciras
# Processing Record 18 of Set 29 | nadym
# Processing Record 19 of Set 29 | devyatka
# City not found. Skipping...
# Processing Record 20 of Set 29 | puerto colombia
# Processing Record 21 of Set 29 | wahran
# City not found. Skipping...
# Processing Record 22 of Set 29 | wabrzezno
# Processing Record 23 of Set 29 | hearst
# Processing Record 24 of Set 29 | senneterre
# Processing Record 25 of Set 29 | nuuk
# Processing Record 26 of Set 29 | pochinok
# Processing Record 27 of Set 29 | mayo
# Processing Record 28 of Set 29 | whitley bay
# Processing Record 29 of Set 29 | halifax
# Processing Record 30 of Set 29 | minna
# Processing Record 31 of Set 29 | bac lieu
# Processing Record 32 of Set 29 | san vicente
# Processing Record 33 of Set 29 | pingchen
# City not found. Skipping...
# Processing Record 34 of Set 29 | ust-maya
# Processing Record 35 of Set 29 | lucapa
# Processing Record 36 of Set 29 | bambanglipuro
# Processing Record 37 of Set 29 | barcelos
# Processing Record 38 of Set 29 | kaihua
# Processing Record 39 of Set 29 | tiruvottiyur
# City not found. Skipping...
# Processing Record 40 of Set 29 | bastia
# Processing Record 41 of Set 29 | chodavaram
# Processing Record 42 of Set 29 | paragominas
# Processing Record 43 of Set 29 | general roca
# Processing Record 44 of Set 29 | richards bay
# Processing Record 45 of Set 29 | drummondville
# Processing Record 46 of Set 29 | ketchikan
# Processing Record 47 of Set 29 | sabang
# Processing Record 48 of Set 29 | chokwe
# Processing Record 49 of Set 29 | houlung
# City not found. Skipping...
# Processing Record 50 of Set 29 | san-pedro
# Processing Record 1 of Set 30 | bandarbeyla
# Processing Record 2 of Set 30 | tigil
# Processing Record 3 of Set 30 | huarmey
# Processing Record 4 of Set 30 | doha
# Processing Record 5 of Set 30 | mitu
# Processing Record 6 of Set 30 | vanavara
# Processing Record 7 of Set 30 | alappuzha
# Processing Record 8 of Set 30 | cabedelo
# Processing Record 9 of Set 30 | maniitsoq
# Processing Record 10 of Set 30 | boyolangu
# Processing Record 11 of Set 30 | mogadishu
# Processing Record 12 of Set 30 | rosetta
# Processing Record 13 of Set 30 | pacifica
# Processing Record 14 of Set 30 | yaan
# Processing Record 15 of Set 30 | hamilton
# Processing Record 16 of Set 30 | kendari
# Processing Record 17 of Set 30 | narasannapeta
# Processing Record 18 of Set 30 | mooi river
# City not found. Skipping...
# Processing Record 19 of Set 30 | satitoa
# City not found. Skipping...
# Processing Record 20 of Set 30 | sobolevo
# Processing Record 21 of Set 30 | eureka
# Processing Record 22 of Set 30 | toulepleu
# City not found. Skipping...
# Processing Record 23 of Set 30 | uruzgan
# Processing Record 24 of Set 30 | laguna
# Processing Record 25 of Set 30 | shanghai
# Processing Record 26 of Set 30 | jijiga
# Processing Record 27 of Set 30 | mullaitivu
# City not found. Skipping...
# Processing Record 28 of Set 30 | lahad datu
# Processing Record 29 of Set 30 | naze
# Processing Record 30 of Set 30 | chase
# Processing Record 31 of Set 30 | nakamura
# Processing Record 32 of Set 30 | denpasar
# Processing Record 33 of Set 30 | acandi
# Processing Record 34 of Set 30 | marovoay
# Processing Record 35 of Set 30 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 30 | lohja
# Processing Record 37 of Set 30 | biloxi
# Processing Record 38 of Set 30 | bose
# Processing Record 39 of Set 30 | hovd
# Processing Record 40 of Set 30 | manaus
# Processing Record 41 of Set 30 | adre
# Processing Record 42 of Set 30 | babanusah
# City not found. Skipping...
# Processing Record 43 of Set 30 | mustasaari
# Processing Record 44 of Set 30 | ndende
# Processing Record 45 of Set 30 | byron bay
# Processing Record 46 of Set 30 | arinos
# Processing Record 47 of Set 30 | shelburne
# Processing Record 48 of Set 30 | soubre
# Processing Record 49 of Set 30 | patrocinio
# Processing Record 50 of Set 30 | ponta delgada
# Processing Record 1 of Set 31 | pachino
# Processing Record 2 of Set 31 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 31 | grand gaube
# Processing Record 4 of Set 31 | abalak
# Processing Record 5 of Set 31 | vryburg
# Processing Record 6 of Set 31 | cap malheureux
# Processing Record 7 of Set 31 | kisangani
# Processing Record 8 of Set 31 | herat
# Processing Record 9 of Set 31 | mbabane
# Processing Record 10 of Set 31 | solnechnyy
# Processing Record 11 of Set 31 | porto novo
# Processing Record 12 of Set 31 | nanakuli
# Processing Record 13 of Set 31 | launceston
# Processing Record 14 of Set 31 | banff
# Processing Record 15 of Set 31 | acajutla
# Processing Record 16 of Set 31 | isahaya
# Processing Record 17 of Set 31 | tabou
# Processing Record 18 of Set 31 | melito di porto salvo
# Processing Record 19 of Set 31 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 31 | shimanovsk
# Processing Record 21 of Set 31 | salamiyah
# Processing Record 22 of Set 31 | lalsot
# Processing Record 23 of Set 31 | burica
# City not found. Skipping...
# Processing Record 24 of Set 31 | naftah
# City not found. Skipping...
# Processing Record 25 of Set 31 | bibiani
# Processing Record 26 of Set 31 | san jeronimo
# Processing Record 27 of Set 31 | qeshm
# Processing Record 28 of Set 31 | yemelyanovo
# Processing Record 29 of Set 31 | khandbari
# Processing Record 30 of Set 31 | loralai
# Processing Record 31 of Set 31 | bay roberts
# Processing Record 32 of Set 31 | juelsminde
# Processing Record 33 of Set 31 | tambovka
# Processing Record 34 of Set 31 | luceville
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Barrow      US  71.2906 -156.7887     -5.80        77
# 1               Faanui      PF -16.4833 -151.7500     81.52        75
# 2              Rikitea      PF -23.1203 -134.9692     77.86        77
# 3             Carauari      BR  -4.8828  -66.8958     79.99        88
# 4    Sao Joao Da Barra      BR -21.6403  -41.0511     80.60        69
# ..                 ...     ...      ...       ...       ...       ...
# 704          Khandbari      NP  27.3747   87.2039     49.35        64
# 705            Loralai      PK  30.3705   68.5980     42.78        42
# 706        Bay Roberts      CA  47.5999  -53.2648     30.00        82
# 707         Juelsminde      DK  55.7088   10.0167     34.00        82
# 708           Tambovka      RU  50.0969  128.0489    -16.60        76
#
#      Cloudiness  Wind Speed       Description
# 0             1       16.11         clear sky
# 1            94       14.65        light rain
# 2            19       13.89        few clouds
# 3            96        0.13        light rain
# 4             0       23.02         clear sky
# ..          ...         ...               ...
# 704          25        2.39  scattered clouds
# 705           0        1.97         clear sky
# 706          64        3.22     broken clouds
# 707         100        8.99        light snow
# 708           0        4.47         clear sky
#
# [709 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
